# %%
# LIBRARIES
import requests
import pandas as pd

## API URL
url = 'https://dadosabertos.camara.leg.br/api/v2/deputados?ordem=ASC&ordenarPor=nome'

## Request
request = requests.get(url)

print(request.status_code)

## create a dataframe returning the json
dataframe = pd.DataFrame(request.json()['dados'])
dataframe
# Out:
# 200
#          id                                                uri  \
# 0    204554  https://dadosabertos.camara.leg.br/api/v2/depu...
# 1    204521  https://dadosabertos.camara.leg.br/api/v2/depu...
# 2    204379  https://dadosabertos.camara.leg.br/api/v2/depu...
# 3    204560  https://dadosabertos.camara.leg.br/api/v2/depu...
# 4    204528  https://dadosabertos.camara.leg.br/api/v2/depu...
# ..      ...                                                ...
# 508  178889  https://dadosabertos.camara.leg.br/api/v2/depu...
# 509  204559  https://dadosabertos.camara.leg.br/api/v2/depu...
# 510  160632  https://dadosabertos.camara.leg.br/api/v2/depu...
# 511  204517  https://dadosabertos.camara.leg.br/api/v2/depu...
# 512  160592  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                 nome   siglaPartido  \
# 0     Abílio Santana            PSC
# 1          Abou Anni          UNIÃO
# 2     Acácio Favacho            MDB
# 3       Adolfo Viana           PSDB
# ...

# %%
## API URL
url = 'https://dadosabertos.camara.leg.br/api/v2/deputados/204554/despesas?ano=2020&pagina=1&itens=100&ordem=ASC&ordenarPor=ano'

request = requests.get(url)

## Request
request = requests.get(url)

print(request.status_code)

## create a dataframe returning the json
dataframe = pd.DataFrame(request.json()['dados'])
dataframe
# Out:
# 200
#      ano  mes                                        tipoDespesa  \
# 0   2020    1  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 1   2020    2  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2   2020    3  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 3   2020    4  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 4   2020    5  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# ..   ...  ...                                                ...
# 95  2020   10                      COMBUSTÍVEIS E LUBRIFICANTES.
# 96  2020   10                      COMBUSTÍVEIS E LUBRIFICANTES.
# 97  2020    7                      COMBUSTÍVEIS E LUBRIFICANTES.
# 98  2020    7                      COMBUSTÍVEIS E LUBRIFICANTES.
# 99  2020    3                      COMBUSTÍVEIS E LUBRIFICANTES.
#
#     codDocumento           tipoDocumento  codTipoDocumento dataDocumento  \
# 0        7004672             Nota Fiscal                 0    2020-01-15
# ...
