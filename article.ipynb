# %%
import requests
import pandas as pd
import re 

## FUNCTION TO GET THE LAST PAGE
def get_last_page(url):       
    r = requests.get(url)    
    url = pd.DataFrame(r.json()['links'])      
    try: 
        last_page = url['href'][3]    
        last_page_number = re.findall('[0-9]+', last_page) 
        last_page_number = last_page_number[3]   
    except:
        last_page_number = 1
        print('No last page')
    return last_page_number

## API URL to get deputies ID
url = 'https://dadosabertos.camara.leg.br/api/v2/deputados?ordem=ASC&ordenarPor=nome'
request = requests.get(url)
df_dep_info = pd.DataFrame(request.json()['dados'])

## lists to store the data and the ids
list = []
id_list = []
name_list = []
partido_list = []
uf_list = []
urlFoto_list = []
email_list = []

for year in range(2020, 2022+1):
    page = 1

    ## counter to select index of rows
    count = 0

    ## request the data for each id
    for id in df_dep_info['id']:          
        url = 'https://dadosabertos.camara.leg.br/api/v2/deputados/'+ str(id) + '/despesas?ano=' + str(year) + '&pagina=' + str(page) + '&itens=100&ordem=ASC&ordenarPor=ano'   
        print(id)
        last_page = get_last_page(url) 
        count += 1  
        

    ## Pagination
        for page in range(1, int(last_page)+1):    
            url = 'https://dadosabertos.camara.leg.br/api/v2/deputados/'+ str(id) + '/despesas?ano=' + str(year) + '&pagina=' + str(page) + '&itens=100&ordem=ASC&ordenarPor=ano' 
            r2 = requests.get(url)
            df_expenses = pd.DataFrame(r2.json()['dados'])        
            list.append(df_expenses)

            ## counting how many rows appears
            count_rows = len(r2.json()['dados'])

            for i in range(count_rows):
                id_list.append(id)
                name_list.append(df_dep_info['nome'][count-1])
                partido_list.append(df_dep_info['siglaPartido'][count-1])
                uf_list.append(df_dep_info['siglaUf'][count-1])
                urlFoto_list.append(df_dep_info['urlFoto'][count-1])
                email_list.append(df_dep_info['email'][count-1])
        

## The line below will allow us to transform our list into a dataframe
df_expenses = pd.concat(list)

## add the columns information to the dataframe
df_expenses['id'] = id_list
df_expenses['nome'] = name_list
df_expenses['siglaPartido'] = partido_list
df_expenses['siglaUf'] = uf_list
df_expenses['urlFoto'] = urlFoto_list
df_expenses['email'] = email_list

## Organize the dataframe
df_expenses = df_expenses[['ano','mes', 'id', 'nome', 'siglaPartido', 'siglaUf', 'urlFoto', 'email', 'tipoDespesa', 'dataDocumento', 'valorDocumento', 'urlDocumento', 'nomeFornecedor', 'cnpjCpfFornecedor']].copy()

## Save the dataframe in a csv file
df_expenses.to_csv('expenses.csv', index=False)

# %%
df_expenses

# %%
df_expenses = df_expenses[['ano','mes', 'id', 'nome', 'siglaPartido', 'siglaUf', 'urlFoto', 'email', 'tipoDespesa', 'dataDocumento', 'valorDocumento', 'urlDocumento', 'nomeFornecedor', 'cnpjCpfFornecedor']].copy()

# %%
df_expenses.to_csv('expenses.csv', index=False)
# Out:
#      ano  mes      id            nome siglaPartido siglaUf  \
# 0   2020    1  204554  Abílio Santana          PSC      BA
# 1   2020    2  204554  Abílio Santana          PSC      BA
# 2   2020    3  204554  Abílio Santana          PSC      BA
# 3   2020    4  204554  Abílio Santana          PSC      BA
# 4   2020    5  204554  Abílio Santana          PSC      BA
# ..   ...  ...     ...             ...          ...     ...
# 82  2022    4  160592     Zeca Dirceu           PT      PR
# 83  2022    4  160592     Zeca Dirceu           PT      PR
# 84  2022    4  160592     Zeca Dirceu           PT      PR
# 85  2022    4  160592     Zeca Dirceu           PT      PR
# 86  2022    4  160592     Zeca Dirceu           PT      PR
#
#                                               urlFoto  \
# 0   https://www.camara.leg.br/internet/deputado/ba...
# 1   https://www.camara.leg.br/internet/deputado/ba...
# 2   https://www.camara.leg.br/internet/deputado/ba...
# 3   https://www.camara.leg.br/internet/deputado/ba...
# 4   https://www.camara.leg.br/internet/deputado/ba...
# ..                                                ...
# 82  https://www.camara.leg.br/internet/deputado/ba...
# 83  https://www.camara.leg.br/internet/deputado/ba...
# 84  https://www.camara.leg.br/internet/deputado/ba...
# 85  https://www.camara.leg.br/internet/deputado/ba...
# 86  https://www.camara.leg.br/internet/deputado/ba...
#
#                               email  \
# 0   dep.abiliosantana@camara.leg.br
# 1   dep.abiliosantana@camara.leg.br
# 2   dep.abiliosantana@camara.leg.br
# 3   dep.abiliosantana@camara.leg.br
# 4   dep.abiliosantana@camara.leg.br
# ..                              ...
# 82     dep.zecadirceu@camara.leg.br
# 83     dep.zecadirceu@camara.leg.br
# 84     dep.zecadirceu@camara.leg.br
# 85     dep.zecadirceu@camara.leg.br
# 86     dep.zecadirceu@camara.leg.br
#
#                                           tipoDespesa dataDocumento  \
# 0   MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...    2020-01-15
# 1   MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...    2020-02-12
# 2   MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...    2020-03-13
# 3   MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...    2020-04-13
# 4   MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...    2020-05-13
# ..                                                ...           ...
# 82                            PASSAGEM AÉREA - SIGEPA    2022-04-28
# 83                            PASSAGEM AÉREA - SIGEPA    2022-04-29
# 84                            PASSAGEM AÉREA - SIGEPA    2022-04-29
# 85                            PASSAGEM AÉREA - SIGEPA    2022-04-29
# 86                            PASSAGEM AÉREA - SIGEPA    2022-04-29
#
#     valorDocumento                                       urlDocumento  \
# 0           132.76  https://www.camara.leg.br/cota-parlamentar/doc...
# 1           162.27  https://www.camara.leg.br/cota-parlamentar/doc...
# 2           284.36  https://www.camara.leg.br/cota-parlamentar/doc...
# 3            80.96  https://www.camara.leg.br/cota-parlamentar/doc...
# 4            65.32  https://www.camara.leg.br/cota-parlamentar/doc...
# ..             ...                                                ...
# 82         1373.52                                               None
# 83         1376.86                                               None
# 84           49.00                                               None
# 85           69.00                                               None
# 86          599.81                                               None
#
#                                   nomeFornecedor cnpjCpfFornecedor
# 0   COMPANHIA DE ELETRICIDADE DO ESTADO DA BAHIA    15139629000194
# 1   COMPANHIA DE ELETRICIDADE DO ESTADO DA BAHIA    15139629000194
# 2   COMPANHIA DE ELETRICIDADE DO ESTADO DA BAHIA    15139629000194
# 3   COMPANHIA DE ELETRICIDADE DO ESTADO DA BAHIA    15139629000194
# 4   COMPANHIA DE ELETRICIDADE DO ESTADO DA BAHIA    15139629000194
# ..                                           ...               ...
# 82                                           TAM
# 83                                           TAM
# 84                                           TAM
# 85                                           TAM
# 86                                           TAM
#
# [364979 rows x 14 columns]
